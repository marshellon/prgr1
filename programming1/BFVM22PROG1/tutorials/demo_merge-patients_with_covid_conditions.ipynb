# %%
import pandas as pd

# %%
conditions = pd.read_csv("data/conditions.csv") 
patients = pd.read_csv("data/patients.csv") 
observations = pd.read_csv("data/observations.csv") 
care_plans = pd.read_csv("data/careplans.csv") 
encounters = pd.read_csv("data/encounters.csv")

# %%
#First let select all the patients with covid. 
covid_conditions = conditions[conditions.CODE == 840539006]

# %%
len(covid_conditions['PATIENT'].unique())
# Out:
# 8820

# %%
covid_conditions.head()
# Out:
#          START        STOP                               PATIENT  \
# 4   2020-03-01  2020-03-30  f0f3bc8d-ef38-49ce-a2bd-dfdda982b271
# 11  2020-03-13  2020-04-14  067318a4-db8f-447f-8b6e-f2f61e9baaa5
# 23  2020-03-11  2020-04-15  ae9efba3-ddc4-43f9-a781-f72019388548
# 30  2020-03-02  2020-04-07  199c586f-af16-4091-9998-ee4cfc02ee7a
# 37  2020-03-02  2020-03-18  353016ea-a0ff-4154-85bb-1cf8b6cedf20
#
#                                ENCOUNTER       CODE DESCRIPTION
# 4   681c380b-3c84-4c55-80a6-db3d9ea12fee  840539006    COVID-19
# 11  1ea74a77-3ad3-4948-a9cc-3084462035d6  840539006    COVID-19
# 23  eeab7c2d-71ba-4e04-af16-87a01dce7d54  840539006    COVID-19
# 30  8333efdf-f7bf-43bb-b73f-2b663d14c1ad  840539006    COVID-19
# 37  8d502eec-afc0-4639-b298-a152a16d492a  840539006    COVID-19

# %%
len(patients['Id'].unique())
# Out:
# 12352

# %%
len(patients)
# Out:
# 12352

# %%
len(covid_conditions)
# Out:
# 8820

# %%
patients.head()
# Out:
#                                      Id   BIRTHDATE DEATHDATE          SSN  \
# 0  f0f3bc8d-ef38-49ce-a2bd-dfdda982b271  2017-08-24       NaN  999-68-6630
# 1  067318a4-db8f-447f-8b6e-f2f61e9baaa5  2016-08-01       NaN  999-15-5895
# 2  ae9efba3-ddc4-43f9-a781-f72019388548  1992-06-30       NaN  999-27-3385
# 3  199c586f-af16-4091-9998-ee4cfc02ee7a  2004-01-09       NaN  999-73-2461
# 4  353016ea-a0ff-4154-85bb-1cf8b6cedf20  1996-11-15       NaN  999-60-7372
#
#      DRIVERS    PASSPORT PREFIX        FIRST        LAST SUFFIX  ...  \
# 0        NaN         NaN    NaN   Jacinto644     Kris249    NaN  ...
# 1        NaN         NaN    NaN      Alva958  Krajcik437    NaN  ...
# 2  S99971451  X53218815X    Mr.    Jayson808    Fadel536    NaN  ...
# 3  S99956432         NaN    NaN     Jimmie93   Harris789    NaN  ...
# 4  S99917327  X58903159X    Mr.  Gregorio366      Auer97    NaN  ...
#
#                        BIRTHPLACE                         ADDRESS  \
# ...

# %%
pd.concat?

# %%
import numpy as np
df_01 = pd.DataFrame(np.random.randn(3,4))
print(df_01)
df_02 = pd.DataFrame(np.random.randn(2,5))
print(df_02)
# Out:
#           0         1         2         3
# 0  0.274763 -1.074099 -2.322613 -0.157516
# 1 -0.861184  1.106638  1.021671 -0.088164
# 2 -0.197057  1.020507 -0.595818 -1.358305
#           0         1         2         3         4
# 0 -0.921646  0.317960  0.489643 -1.083344 -0.544292
# 1 -0.204342 -0.261794 -0.150072  0.477407  0.610228

# %%
pd.concat([df_01, df_02], ignore_index =True)
# Out:
#           0         1         2         3         4
# 0  0.274763 -1.074099 -2.322613 -0.157516       NaN
# 1 -0.861184  1.106638  1.021671 -0.088164       NaN
# 2 -0.197057  1.020507 -0.595818 -1.358305       NaN
# 3 -0.921646  0.317960  0.489643 -1.083344 -0.544292
# 4 -0.204342 -0.261794 -0.150072  0.477407  0.610228

# %%
pd.DataFrame.join?

# %%
covid_conditions['Id'] = covid_conditions['PATIENT']
# Out:
# <ipython-input-48-12c98bc8e45e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   covid_conditions['Id'] = covid_conditions['PATIENT']

# %%
covid_conditions.head()
# Out:
#          START        STOP                               PATIENT  \
# 4   2020-03-01  2020-03-30  f0f3bc8d-ef38-49ce-a2bd-dfdda982b271
# 11  2020-03-13  2020-04-14  067318a4-db8f-447f-8b6e-f2f61e9baaa5
# 23  2020-03-11  2020-04-15  ae9efba3-ddc4-43f9-a781-f72019388548
# 30  2020-03-02  2020-04-07  199c586f-af16-4091-9998-ee4cfc02ee7a
# 37  2020-03-02  2020-03-18  353016ea-a0ff-4154-85bb-1cf8b6cedf20
#
#                                ENCOUNTER       CODE DESCRIPTION  \
# 4   681c380b-3c84-4c55-80a6-db3d9ea12fee  840539006    COVID-19
# 11  1ea74a77-3ad3-4948-a9cc-3084462035d6  840539006    COVID-19
# 23  eeab7c2d-71ba-4e04-af16-87a01dce7d54  840539006    COVID-19
# 30  8333efdf-f7bf-43bb-b73f-2b663d14c1ad  840539006    COVID-19
# 37  8d502eec-afc0-4639-b298-a152a16d492a  840539006    COVID-19
#
#                                       Id
# 4   f0f3bc8d-ef38-49ce-a2bd-dfdda982b271
# 11  067318a4-db8f-447f-8b6e-f2f61e9baaa5
# 23  ae9efba3-ddc4-43f9-a781-f72019388548
# ...

# %%
joined = covid_conditions.set_index('Id').join(patients.set_index('Id'), how = 'right')

# %%
len(joined)
# Out:
# 12352

# %%
joined.head()
# Out:
#                                            START        STOP  \
# Id
# f0f3bc8d-ef38-49ce-a2bd-dfdda982b271  2020-03-01  2020-03-30
# 067318a4-db8f-447f-8b6e-f2f61e9baaa5  2020-03-13  2020-04-14
# ae9efba3-ddc4-43f9-a781-f72019388548  2020-03-11  2020-04-15
# 199c586f-af16-4091-9998-ee4cfc02ee7a  2020-03-02  2020-04-07
# 353016ea-a0ff-4154-85bb-1cf8b6cedf20  2020-03-02  2020-03-18
#
#                                                                    PATIENT  \
# Id
# f0f3bc8d-ef38-49ce-a2bd-dfdda982b271  f0f3bc8d-ef38-49ce-a2bd-dfdda982b271
# 067318a4-db8f-447f-8b6e-f2f61e9baaa5  067318a4-db8f-447f-8b6e-f2f61e9baaa5
# ae9efba3-ddc4-43f9-a781-f72019388548  ae9efba3-ddc4-43f9-a781-f72019388548
# 199c586f-af16-4091-9998-ee4cfc02ee7a  199c586f-af16-4091-9998-ee4cfc02ee7a
# 353016ea-a0ff-4154-85bb-1cf8b6cedf20  353016ea-a0ff-4154-85bb-1cf8b6cedf20
#
#                                                                  ENCOUNTER  \
# Id
# ...

# %%
pd.DataFrame.join?

# %%
pd.merge?

# %%
joined = pd.merge(covid_conditions, patients, how = 'inner', left_on='PATIENT' , right_on='Id')

# %%
len(joined)
# Out:
# 8820
